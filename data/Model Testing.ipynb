# %%
import pandas as pd
import numpy as np
import pickle

# %%
with open('Decision_tree_model.pkl', 'rb') as f:
    dt_clf = pickle.load(f)

# %%
dt_clf
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=4, min_samples_split=10,
#                        random_state=1)

# %%
dt_clf.feature_names_in_
# Out:
# array(['Age', 'Experience', 'Income', 'Family', 'CCAvg', 'Education',
#        'Mortgage', 'Securities.Account', 'CD.Account', 'Online',
#        'CreditCard'], dtype=object)

# %% [markdown]
# ### user_input

# %%
features_list = ['ID', 'Age', 'Experience', 'Income', 'ZIP.Code', 'Family', 'CCAvg',
       'Education', 'Mortgage', 'Securities.Account',
       'CD.Account', 'Online', 'CreditCard']

ID = 5
Age = 29
Experience = 5
Income = 50
features_list[4] = ZIP_Code = 431710
Family = 4
CCAvg = 2.7 
Education = 2 
Mortgage = 1
features_list[9] = Securities_Account = 0
features_list[10] = CD_Account = 0
Online = 1
CreditCard = 1



test_array = np.array(features_list, ndmin = 2)
test_array
# Out:
# array([['ID', 'Age', 'Experience', 'Income', '431710', 'Family', 'CCAvg',
#         'Education', 'Mortgage', '0', '0', 'Online', 'CreditCard']],
#       dtype='<U11')

# %%
with open('Decision_tree_model.pkl', 'rb') as f:
    dt_clf = pickle.load(f)

features_list = ['ID', 'Age', 'Experience', 'Income', 'ZIP.Code', 'Family', 'CCAvg',
       'Education', 'Mortgage', 'Securities.Account',
       'CD.Account', 'Online', 'CreditCard']

ID = 5
Age = 29
Experience = 5
Income = 50
features_list[4] = ZIP_Code = 431710
Family = 4
CCAvg = 2.7 
Education = 2 
Mortgage = 1
features_list[9] = Securities_Account = 0
features_list[10] = CD_Account = 0
Online = 1
CreditCard = 1



test_array = np.array(features_list, ndmin = 2)
test_array

predicted_class = dt_clf.predict(test_array)

# %%
# prediction_utils.py

import pickle
import numpy as np

class PredictModel:
    def __init__(self, model_path='Decision_tree_model.pkl'):
        # Load the Decision Tree model during class initialization
        with open(model_path, 'rb') as f:
            self.dt_clf = pickle.load(f)
        
        # List of features used by the model
        self.features_list = ['Age', 'Experience', 'Income', 'Family', 'CCAvg',
                              'Education', 'Mortgage', 'Securities.Account',
                              'CD.Account', 'Online', 'CreditCard']

    def create_test_array(self, age, experience, income, family, cc_avg, education, mortgage, securities_account, cd_account, online, credit_card):
        # Create a test array without 'ID' and 'ZIP.Code'
        test_array = np.array([age, experience, income, family, cc_avg, education, mortgage, securities_account, cd_account, online, credit_card], ndmin=2)
        return test_array

    def predict_class(self, test_array):
        # Predict the class using the loaded Decision Tree model
        predicted_class = self.dt_clf.predict(test_array)
        return predicted_class[0]
# Out:
# Predicted Class: 1
# C:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
model_predictor = PredictModel()

    # Input values (replace with user inputs)
    age = 29
    experience = 5
    income = 50
    family = 4
    cc_avg = 2.7
    education = 2
    mortgage = 1
    securities_account = 0
    cd_account = 0
    online = 1
    credit_card = 1

    # Create a test array without 'ID' and 'ZIP.Code'
    test_array = model_predictor.create_test_array(age, experience, income, family, cc_avg, education, mortgage, securities_account, cd_account, online, credit_card)

    # Predict the class
    predicted_class = model_predictor.predict_class(test_array)

    # Print the predicted class
    print("Predicted Class:", predicted_class)
